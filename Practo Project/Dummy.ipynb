# %%
#recommendation.insert(9,"nan")
#recommendation.insert(10,"nan")

# %% [markdown]
# ```python
# experience=soup.find_all('div',{"data-qa-id":"doctor_experience"})
# re.findall(r"(\d+)<",str(experience))
# ```

# %%
Gynecologist_df1
Dentist_df1
General_Physician_df1
Dermatologist_df1
ENT_df1
Homoeopath_df1
Ayurveda_df1

# %% [markdown]
# ```python
# page = requests.get("""url""")
# soup = BeautifulSoup(page.text)
# Doctor_name=[]
# for i in soup.find_all("h2",class_="doctor-name"):
#     Doctor_name.append(i.text)
# print(Doctor_name)
# print(len(Doctor_name))
# print("--"*50)
#
# City_name=[]
# for i in soup.find_all("span",class_="u-t-capitalize"):
#     City_name.append(i.text)
# print(City_name)
# print(len(City_name))
# print("--"*50)
#
# Area=[]
# for i in soup.find_all("span",attrs={"data-qa-id":"practice_locality"}):
#     Area.append(i.text)
# print(Area)
# print(len(Area))
# print("--"*50)
#
# q = soup.find_all("span",attrs={"data-qa-id":"consultation_fee"})
# q
# consultation_fee=re.findall(r"\d+\d+\w+",str(q))
# print(consultation_fee)
# print(len(consultation_fee))
# print("--"*50)
#
# recommendation=[]
# for i in soup.find_all("span",attrs={"data-qa-id":"doctor_recommendation"}):
#         recommendation.append(i.text)
# #recommendation.insert(2,"nan")
# print(recommendation)
# print(len(recommendation))
# print("--"*50)
#
# s=soup.find_all('div',{"data-qa-id":"doctor_experience"})
# experience = re.findall(r"(\d+)<",str(s))
# print(experience)
# print(len(experience))
# print("--"*50)
# ````

# %% [markdown]
# ```pthon
# Hospital_name=[]
# for i in soup.find_all("span",class_="u-c-pointer u-t-hover-underline"):
#     Hospital_name.append(i.text)
# Hospital_name.remove('\xa0+ 1 more')
# Hospital_name.remove('\xa0+ 1 more')
# Hospital_name.remove('\xa0+ 1 more')
# Hospital_name.remove('\xa0+ 1 more')
# #Hospital_name.remove('\xa0+ 1 more')
#
# print(Hospital_name)
# len(Hospital_name)
#
# p = soup.find_all("div",class_="u-grey_3-text")
# p
# Specialist = re.findall(r"()<",str(p))
# Specialist
# #Specialist.remove('')
# len(Specialist)
#
# dictionary = {
#     "Doctor_name":Doctor_name,
#     "Specialist":Specialist,
#     "Experience":experience,
#     "City_name":City_name,
#     "Area":Area,
#     "Hospital_name":Hospital_name,
#     "Consultation_fee":consultation_fee,
#     "Recommendation":recommendation,
#
# }
#
# Homoeopath_df1 = pd.DataFrame(dictionary)
# Homoeopath_df1
#
# df.to_csv("batch_191.csv")
#
# import os
# os.getcwd()
#
# pwd
#
# df = pd.read_csv("practo.csv")
#
# df.drop(['Unnamed:0'],axis=1,inplace=True)
#
# final_df = pd.concat([df,Dentist_df1],axis=0)
# final_df
# ```

# %%
Dentist_df,General_Physician_df1,Dermatologist_df1,ENT_df1,Homoeopath_df1,Homoeopath_df1

# %%
import requests
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from bs4 import BeautifulSoup

# %%
page = requests.get('https://www.practo.com/search/doctors?results_type=doctor&q=%5B%7B%22word%22%3A%22Gynecologist%2Fobstetrician%22%2C%22autocompleted%22%3Atrue%2C%22category%22%3A%22subspeciality%22%7D%5D&city=Hyderabad')

# %%
page
# Out:
# <Response [200]>

# %%
BeautifulSoup(page.text)
# Out:
# <!DOCTYPE html>
# <html><head><title>Best Gynecologist Obstetricians In Hyderabad - Instant Appointment Booking, View Fees, Feedbacks | Practo</title><meta content="Best Gynecologist obstetricians in Hyderabad. Book Doctor's Appointment Online, View Fees, User feedbacks, Address &amp; Phone Numbers of Gynecologist/obstetricians in Hyderabad | Practo" name="description"/><meta charset="utf-8"/><meta content="ie=edge" http-equiv="x-ua-compatible"/><script nonce="xeHu5mdYyYF0bzvVxIlC0i3IK6d8ZLCe" type="text/javascript">(function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':
#                       new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],
#                       j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src=
#                       'https://www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);
# ...

# %%
soup = BeautifulSoup(page.text)

# %%
Doctor_name=soup.find_all("h2")

# %%
soup.find_all("h2")[1].text
# Out:
# 'Dr. K. Suma'

# %%
soup.find_all("h2",class_="doctor-name")
# Out:
# [<h2 class="doctor-name" data-qa-id="doctor_name">Dr. K. Suma</h2>,
#  <h2 class="doctor-name" data-qa-id="doctor_name">Dr. G Durga Rao</h2>,
#  <h2 class="doctor-name" data-qa-id="doctor_name">Dr. Anuradha Panda</h2>,
#  <h2 class="doctor-name" data-qa-id="doctor_name">Dr. Shalni .S</h2>,
#  <h2 class="doctor-name" data-qa-id="doctor_name">Dr. Vangallu Padmini Silpa</h2>,
#  <h2 class="doctor-name" data-qa-id="doctor_name">Dr. Puja Lavania</h2>,
#  <h2 class="doctor-name" data-qa-id="doctor_name">Dr. Andal Reddy</h2>,
#  <h2 class="doctor-name" data-qa-id="doctor_name">Dr. Jasmin Rath</h2>,
#  <h2 class="doctor-name" data-qa-id="doctor_name">Dr. M.Kalpana</h2>,
#  <h2 class="doctor-name" data-qa-id="doctor_name">Dr. B Kiranmayee</h2>]

# %%
Doctor_name=[]
for i in soup.find_all("h2",class_="doctor-name"):
    Doctor_name.append(i.text)
print(Doctor_name)
# Out:
# ['Dr. G Durga Rao', 'Dr. Shalni .S', 'Dr. Lavanya. B', 'Dr. Sai Lakshmi Daayana', 'Dr. Puja Lavania', 'Dr. Sarada Mallemala', 'Dr. Priyamvada Reddy Cherukuru', 'Dr. Archana Anil Nagaonkar', 'Dr. K. Suma', 'Dr. Radhika Reddy Pingili']

# %%
soup.find_all("h2",class_="doctor-name")
# Out:
# [<h2 class="doctor-name" data-qa-id="doctor_name">Dr. G Durga Rao</h2>,
#  <h2 class="doctor-name" data-qa-id="doctor_name">Dr. Shalni .S</h2>,
#  <h2 class="doctor-name" data-qa-id="doctor_name">Dr. Lavanya. B</h2>,
#  <h2 class="doctor-name" data-qa-id="doctor_name">Dr. Sai Lakshmi Daayana</h2>,
#  <h2 class="doctor-name" data-qa-id="doctor_name">Dr. Puja Lavania</h2>,
#  <h2 class="doctor-name" data-qa-id="doctor_name">Dr. Sarada Mallemala</h2>,
#  <h2 class="doctor-name" data-qa-id="doctor_name">Dr. Priyamvada Reddy Cherukuru</h2>,
#  <h2 class="doctor-name" data-qa-id="doctor_name">Dr. Archana Anil Nagaonkar</h2>,
#  <h2 class="doctor-name" data-qa-id="doctor_name">Dr. K. Suma</h2>,
#  <h2 class="doctor-name" data-qa-id="doctor_name">Dr. Radhika Reddy Pingili</h2>]

# %%
soup.find_all("div",class_="u-border-general--bottom")[0].text
# Out:
# 'ADMulberry Super Speciality Dental and Gynecology1 Gynecologist/Obstetrician10 - 11 years experienceNallagandla₹300 - ₹500Consultation Fees100%19 Patient StoriesBook Clinic Visit'
